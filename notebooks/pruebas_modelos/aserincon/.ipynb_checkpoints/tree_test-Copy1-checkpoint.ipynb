# %% [markdown]
# # TREE DECISION MODEL

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn.metrics import ConfusionMatrixDisplay, classification_report

# %%
import sys

import sys  
sys.path.insert(0, '../../../scripts/')

import eda_tools

# %% [markdown]
# ## Data

# %%
# Model 1 -> Lasso selected variables
full_train = pd.read_csv("../../../data/csev/model_3/trainCSEV.csv")
full_test = pd.read_csv("../../../data/csev/model_3/testCSEV.csv")

# %%
Y_train = full_train['C_SEV']
X_train = full_train.drop(['C_SEV'], axis=1)
Y_train.value_counts()
# Out:
# 1    27796
# 0    27794
# Name: C_SEV, dtype: int64

# %%
X_train.columns
# Out:
# Index(['C_MNTH', 'C_WDAY', 'C_RCFG', 'C_RSUR', 'C_RALN', 'C_TRAF', 'C_HOUR_N',
#        'C_CONF_TO', 'C_CONF_TS'],
#       dtype='object')

# %%
categorical = ['C_MNTH', 'C_WDAY', 'C_RCFG', 'C_RSUR', 'C_RALN', 'C_TRAF', 'C_HOUR_N',
       'C_CONF_TO', 'C_CONF_TS']

XY_train = X_train.copy()
XY_train['C_SEV'] = Y_train

fig, axes = plt.subplots(5, 2, figsize=(15, 35), sharey=False)
fig.suptitle('Categorial Values by Severity')

i = 0
j = 0
for cat in categorical:
    sns.countplot(data = XY_train, x = cat, hue = 'C_SEV', ax = axes[i,j]);
    if (j == 0): 
        j = 1
    else:
        j = 0
        i += 1

# %%
# X_train = X_train.drop(['C_HOUR_M'], axis=1)

# %%
Y_test = full_test['C_SEV']
X_test = full_test.drop(['C_SEV'], axis=1)
Y_test.value_counts()
# Out:
# 1    351139
# 0      6949
# Name: C_SEV, dtype: int64

# %%
# X_test = X_test.drop(['C_HOUR_M'], axis=1)

# %% [markdown]
# ## Tree

# %%
treeModel = DecisionTreeClassifier(random_state=0)

# %%
treeModel.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
Y_pred = treeModel.predict(X_test)

# %% [markdown]
# ## Evaluation

# %%
metrics.accuracy_score(Y_test, Y_pred)
# Out:
# 0.6991046893501038

# %%
titles_options = [
    ("Matriz de confusión", None),
    ("Matriz de confusión normalizada", "true"),
]
for title, normalize in titles_options:
    disp = ConfusionMatrixDisplay.from_estimator(
        treeModel,
        X_test,
        Y_test,
        display_labels=['Con Fall.', 'Sin Fall.'],
        cmap=plt.cm.Blues,
        normalize=normalize,
    )
    disp.ax_.set_title(title)

    print(title)
    print(disp.confusion_matrix)

plt.show()
# Out:
# Matriz de confusión
# [[  4435   2514]
#  [105233 245906]]
# Matriz de confusión normalizada
# [[0.63822133 0.36177867]
#  [0.29969044 0.70030956]]

# %%
print("Classification Report")
print(classification_report(Y_test, Y_pred))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.04      0.64      0.08      6949
#            1       0.99      0.70      0.82    351139
#
#     accuracy                           0.70    358088
#    macro avg       0.52      0.67      0.45    358088
# weighted avg       0.97      0.70      0.81    358088
